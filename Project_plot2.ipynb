# %%
import pandas as pd # import and manage datasets
import numpy as np # mathematic library

df = pd.read_excel('Theshiftproject_electricitygenerationbyenergysource.xls')
year = df['Year'][0:35]
A = np.zeros((35,9))

B = df.loc[df['Year'] == 1980]
A[0][0] = sum(B['Biomass and Waste'][1:174].tolist())
A[0][1] = sum(B['Geothermal'][1:174].tolist())
A[0][2] = sum(B['Hydroelectric'][1:174].tolist())
A[0][3] = sum(B['Nuclear'][1:174].tolist())
A[0][4] = sum(B['Solar Tide Wave'][1:174].tolist())
A[0][5] = sum(B['Wind'][1:174].tolist())
A[0][6] = sum(B['Coal'][1:174].tolist())
A[0][7] = sum(B['Gas'][1:174].tolist())
A[0][8] = sum(B['Oil'][1:174].tolist())

B = df.loc[df['Year'] == 1981]
A[1][0] = sum(B['Biomass and Waste'][1:174].tolist())
A[1][1] = sum(B['Geothermal'][1:174].tolist())
A[1][2] = sum(B['Hydroelectric'][1:174].tolist())
A[1][3] = sum(B['Nuclear'][1:174].tolist())
A[1][4] = sum(B['Solar Tide Wave'][1:174].tolist())
A[1][5] = sum(B['Wind'][1:174].tolist())
A[1][6] = sum(B['Coal'][1:174].tolist())
A[1][7] = sum(B['Gas'][1:174].tolist())
A[1][8] = sum(B['Oil'][1:174].tolist())

B = df.loc[df['Year'] == 1982]
A[2][0] = sum(B['Biomass and Waste'][1:174].tolist())
A[2][1] = sum(B['Geothermal'][1:174].tolist())
A[2][2] = sum(B['Hydroelectric'][1:174].tolist())
A[2][3] = sum(B['Nuclear'][1:174].tolist())
A[2][4] = sum(B['Solar Tide Wave'][1:174].tolist())
A[2][5] = sum(B['Wind'][1:174].tolist())
A[2][6] = sum(B['Coal'][1:174].tolist())
A[2][7] = sum(B['Gas'][1:174].tolist())
A[2][8] = sum(B['Oil'][1:174].tolist())

B = df.loc[df['Year'] == 1983]
A[3][0] = sum(B['Biomass and Waste'][1:174].tolist())
A[3][1] = sum(B['Geothermal'][1:174].tolist())
A[3][2] = sum(B['Hydroelectric'][1:174].tolist())
A[3][3] = sum(B['Nuclear'][1:174].tolist())
A[3][4] = sum(B['Solar Tide Wave'][1:174].tolist())
A[3][5] = sum(B['Wind'][1:174].tolist())
A[3][6] = sum(B['Coal'][1:174].tolist())
A[3][7] = sum(B['Gas'][1:174].tolist())
A[3][8] = sum(B['Oil'][1:174].tolist())

B = df.loc[df['Year'] == 1984]
A[4][0] = sum(B['Biomass and Waste'][1:174].tolist())
A[4][1] = sum(B['Geothermal'][1:174].tolist())
A[4][2] = sum(B['Hydroelectric'][1:174].tolist())
A[4][3] = sum(B['Nuclear'][1:174].tolist())
A[4][4] = sum(B['Solar Tide Wave'][1:174].tolist())
A[4][5] = sum(B['Wind'][1:174].tolist())
A[4][6] = sum(B['Coal'][1:174].tolist())
A[4][7] = sum(B['Gas'][1:174].tolist())
A[4][8] = sum(B['Oil'][1:174].tolist())

B = df.loc[df['Year'] == 1985]
A[5][0] = sum(B['Biomass and Waste'][1:174].tolist())
A[5][1] = sum(B['Geothermal'][1:174].tolist())
A[5][2] = sum(B['Hydroelectric'][1:174].tolist())
A[5][3] = sum(B['Nuclear'][1:174].tolist())
A[5][4] = sum(B['Solar Tide Wave'][1:174].tolist())
A[5][5] = sum(B['Wind'][1:174].tolist())
A[5][6] = sum(B['Coal'][1:174].tolist())
A[5][7] = sum(B['Gas'][1:174].tolist())
A[5][8] = sum(B['Oil'][1:174].tolist())

B = df.loc[df['Year'] == 1986]
A[6][0] = sum(B['Biomass and Waste'][1:174].tolist())
A[6][1] = sum(B['Geothermal'][1:174].tolist())
A[6][2] = sum(B['Hydroelectric'][1:174].tolist())
A[6][3] = sum(B['Nuclear'][1:174].tolist())
A[6][4] = sum(B['Solar Tide Wave'][1:174].tolist())
A[6][5] = sum(B['Wind'][1:174].tolist())
A[7][6] = sum(B['Coal'][1:174].tolist())
A[7][7] = sum(B['Gas'][1:174].tolist())
A[7][8] = sum(B['Oil'][1:174].tolist())

B = df.loc[df['Year'] == 1987]
A[7][0] = sum(B['Biomass and Waste'][1:174].tolist())
A[7][1] = sum(B['Geothermal'][1:174].tolist())
A[7][2] = sum(B['Hydroelectric'][1:174].tolist())
A[7][3] = sum(B['Nuclear'][1:174].tolist())
A[7][4] = sum(B['Solar Tide Wave'][1:174].tolist())
A[7][5] = sum(B['Wind'][1:174].tolist())
A[7][6] = sum(B['Coal'][1:174].tolist())
A[7][7] = sum(B['Gas'][1:174].tolist())
A[7][8] = sum(B['Oil'][1:174].tolist())

B = df.loc[df['Year'] == 1988]
A[8][0] = sum(B['Biomass and Waste'][1:174].tolist())
A[8][1] = sum(B['Geothermal'][1:174].tolist())
A[8][2] = sum(B['Hydroelectric'][1:174].tolist())
A[8][3] = sum(B['Nuclear'][1:174].tolist())
A[8][4] = sum(B['Solar Tide Wave'][1:174].tolist())
A[8][5] = sum(B['Wind'][1:174].tolist())
A[8][6] = sum(B['Coal'][1:174].tolist())
A[8][7] = sum(B['Gas'][1:174].tolist())
A[8][8] = sum(B['Oil'][1:174].tolist())

B = df.loc[df['Year'] == 1989]
A[9][0] = sum(B['Biomass and Waste'][1:174].tolist())
A[9][1] = sum(B['Geothermal'][1:174].tolist())
A[9][2] = sum(B['Hydroelectric'][1:174].tolist())
A[9][3] = sum(B['Nuclear'][1:174].tolist())
A[9][4] = sum(B['Solar Tide Wave'][1:174].tolist())
A[9][5] = sum(B['Wind'][1:174].tolist())
A[9][6] = sum(B['Coal'][1:174].tolist())
A[9][7] = sum(B['Gas'][1:174].tolist())
A[9][8] = sum(B['Oil'][1:174].tolist())

B = df.loc[df['Year'] == 1990]
A[10][0] = sum(B['Biomass and Waste'][1:174].tolist())
A[10][1] = sum(B['Geothermal'][1:174].tolist())
A[10][2] = sum(B['Hydroelectric'][1:174].tolist())
A[10][3] = sum(B['Nuclear'][1:174].tolist())
A[10][4] = sum(B['Solar Tide Wave'][1:174].tolist())
A[10][5] = sum(B['Wind'][1:174].tolist())
A[10][6] = sum(B['Coal'][1:174].tolist())
A[10][7] = sum(B['Gas'][1:174].tolist())
A[10][8] = sum(B['Oil'][1:174].tolist())

B = df.loc[df['Year'] == 1991]
A[11][0] = sum(B['Biomass and Waste'][1:174].tolist())
A[11][1] = sum(B['Geothermal'][1:174].tolist())
A[11][2] = sum(B['Hydroelectric'][1:174].tolist())
A[11][3] = sum(B['Nuclear'][1:174].tolist())
A[11][4] = sum(B['Solar Tide Wave'][1:174].tolist())
A[11][5] = sum(B['Wind'][1:174].tolist())
A[11][6] = sum(B['Coal'][1:174].tolist())
A[11][7] = sum(B['Gas'][1:174].tolist())
A[11][8] = sum(B['Oil'][1:174].tolist())

B = df.loc[df['Year'] == 1992]
A[12][0] = sum(B['Biomass and Waste'][1:174].tolist())
A[12][1] = sum(B['Geothermal'][1:174].tolist())
A[12][2] = sum(B['Hydroelectric'][1:174].tolist())
A[12][3] = sum(B['Nuclear'][1:174].tolist())
A[12][4] = sum(B['Solar Tide Wave'][1:174].tolist())
A[12][5] = sum(B['Wind'][1:174].tolist())
A[12][6] = sum(B['Coal'][1:174].tolist())
A[12][7] = sum(B['Gas'][1:174].tolist())
A[12][8] = sum(B['Oil'][1:174].tolist())

B = df.loc[df['Year'] == 1993]
A[13][0] = sum(B['Biomass and Waste'][1:174].tolist())
A[13][1] = sum(B['Geothermal'][1:174].tolist())
A[13][2] = sum(B['Hydroelectric'][1:174].tolist())
A[13][3] = sum(B['Nuclear'][1:174].tolist())
A[13][4] = sum(B['Solar Tide Wave'][1:174].tolist())
A[13][5] = sum(B['Wind'][1:174].tolist())
A[13][6] = sum(B['Coal'][1:174].tolist())
A[13][7] = sum(B['Gas'][1:174].tolist())
A[13][8] = sum(B['Oil'][1:174].tolist())

B = df.loc[df['Year'] == 1994]
A[14][0] = sum(B['Biomass and Waste'][1:174].tolist())
A[14][1] = sum(B['Geothermal'][1:174].tolist())
A[14][2] = sum(B['Hydroelectric'][1:174].tolist())
A[14][3] = sum(B['Nuclear'][1:174].tolist())
A[14][4] = sum(B['Solar Tide Wave'][1:174].tolist())
A[14][5] = sum(B['Wind'][1:174].tolist())
A[14][6] = sum(B['Coal'][1:174].tolist())
A[14][7] = sum(B['Gas'][1:174].tolist())
A[14][8] = sum(B['Oil'][1:174].tolist())

B = df.loc[df['Year'] == 1995]
A[15][0] = sum(B['Biomass and Waste'][1:174].tolist())
A[15][1] = sum(B['Geothermal'][1:174].tolist())
A[15][2] = sum(B['Hydroelectric'][1:174].tolist())
A[15][3] = sum(B['Nuclear'][1:174].tolist())
A[15][4] = sum(B['Solar Tide Wave'][1:174].tolist())
A[15][5] = sum(B['Wind'][1:174].tolist())
A[15][6] = sum(B['Coal'][1:174].tolist())
A[15][7] = sum(B['Gas'][1:174].tolist())
A[15][8] = sum(B['Oil'][1:174].tolist())

B = df.loc[df['Year'] == 1996]
A[16][0] = sum(B['Biomass and Waste'][1:174].tolist())
A[16][1] = sum(B['Geothermal'][1:174].tolist())
A[16][2] = sum(B['Hydroelectric'][1:174].tolist())
A[16][3] = sum(B['Nuclear'][1:174].tolist())
A[16][4] = sum(B['Solar Tide Wave'][1:174].tolist())
A[16][5] = sum(B['Wind'][1:174].tolist())
A[16][6] = sum(B['Coal'][1:174].tolist())
A[16][7] = sum(B['Gas'][1:174].tolist())
A[16][8] = sum(B['Oil'][1:174].tolist())

B = df.loc[df['Year'] == 1997]
A[17][0] = sum(B['Biomass and Waste'][1:174].tolist())
A[17][1] = sum(B['Geothermal'][1:174].tolist())
A[17][2] = sum(B['Hydroelectric'][1:174].tolist())
A[17][3] = sum(B['Nuclear'][1:174].tolist())
A[17][4] = sum(B['Solar Tide Wave'][1:174].tolist())
A[17][5] = sum(B['Wind'][1:174].tolist())
A[17][6] = sum(B['Coal'][1:174].tolist())
A[17][7] = sum(B['Gas'][1:174].tolist())
A[17][8] = sum(B['Oil'][1:174].tolist())

B = df.loc[df['Year'] == 1998]
A[18][0] = sum(B['Biomass and Waste'][1:174].tolist())
A[18][1] = sum(B['Geothermal'][1:174].tolist())
A[18][2] = sum(B['Hydroelectric'][1:174].tolist())
A[18][3] = sum(B['Nuclear'][1:174].tolist())
A[18][4] = sum(B['Solar Tide Wave'][1:174].tolist())
A[18][5] = sum(B['Wind'][1:174].tolist())
A[18][6] = sum(B['Coal'][1:174].tolist())
A[18][7] = sum(B['Gas'][1:174].tolist())
A[18][8] = sum(B['Oil'][1:174].tolist())

B = df.loc[df['Year'] == 1999]
A[19][0] = sum(B['Biomass and Waste'][1:174].tolist())
A[19][1] = sum(B['Geothermal'][1:174].tolist())
A[19][2] = sum(B['Hydroelectric'][1:174].tolist())
A[19][3] = sum(B['Nuclear'][1:174].tolist())
A[19][4] = sum(B['Solar Tide Wave'][1:174].tolist())
A[19][5] = sum(B['Wind'][1:174].tolist())
A[19][6] = sum(B['Coal'][1:174].tolist())
A[19][7] = sum(B['Gas'][1:174].tolist())
A[19][8] = sum(B['Oil'][1:174].tolist())

B = df.loc[df['Year'] == 2000]
A[20][0] = sum(B['Biomass and Waste'][1:174].tolist())
A[20][1] = sum(B['Geothermal'][1:174].tolist())
A[20][2] = sum(B['Hydroelectric'][1:174].tolist())
A[20][3] = sum(B['Nuclear'][1:174].tolist())
A[20][4] = sum(B['Solar Tide Wave'][1:174].tolist())
A[20][5] = sum(B['Wind'][1:174].tolist())
A[20][6] = sum(B['Coal'][1:174].tolist())
A[20][7] = sum(B['Gas'][1:174].tolist())
A[20][8] = sum(B['Oil'][1:174].tolist())

B = df.loc[df['Year'] == 2001]
A[21][0] = sum(B['Biomass and Waste'][1:174].tolist())
A[21][1] = sum(B['Geothermal'][1:174].tolist())
A[21][2] = sum(B['Hydroelectric'][1:174].tolist())
A[21][3] = sum(B['Nuclear'][1:174].tolist())
A[21][4] = sum(B['Solar Tide Wave'][1:174].tolist())
A[21][5] = sum(B['Wind'][1:174].tolist())
A[21][6] = sum(B['Coal'][1:174].tolist())
A[21][7] = sum(B['Gas'][1:174].tolist())
A[21][8] = sum(B['Oil'][1:174].tolist())

B = df.loc[df['Year'] == 2002]
A[22][0] = sum(B['Biomass and Waste'][1:174].tolist())
A[22][1] = sum(B['Geothermal'][1:174].tolist())
A[22][2] = sum(B['Hydroelectric'][1:174].tolist())
A[22][3] = sum(B['Nuclear'][1:174].tolist())
A[22][4] = sum(B['Solar Tide Wave'][1:174].tolist())
A[22][5] = sum(B['Wind'][1:174].tolist())
A[22][6] = sum(B['Coal'][1:174].tolist())
A[22][7] = sum(B['Gas'][1:174].tolist())
A[22][8] = sum(B['Oil'][1:174].tolist())

B = df.loc[df['Year'] == 2003]
A[23][0] = sum(B['Biomass and Waste'][1:174].tolist())
A[23][1] = sum(B['Geothermal'][1:174].tolist())
A[23][2] = sum(B['Hydroelectric'][1:174].tolist())
A[23][3] = sum(B['Nuclear'][1:174].tolist())
A[23][4] = sum(B['Solar Tide Wave'][1:174].tolist())
A[23][5] = sum(B['Wind'][1:174].tolist())
A[23][6] = sum(B['Coal'][1:174].tolist())
A[23][7] = sum(B['Gas'][1:174].tolist())
A[23][8] = sum(B['Oil'][1:174].tolist())

B = df.loc[df['Year'] == 2004]
A[24][0] = sum(B['Biomass and Waste'][1:174].tolist())
A[24][1] = sum(B['Geothermal'][1:174].tolist())
A[24][2] = sum(B['Hydroelectric'][1:174].tolist())
A[24][3] = sum(B['Nuclear'][1:174].tolist())
A[24][4] = sum(B['Solar Tide Wave'][1:174].tolist())
A[24][5] = sum(B['Wind'][1:174].tolist())
A[24][6] = sum(B['Coal'][1:174].tolist())
A[24][7] = sum(B['Gas'][1:174].tolist())
A[24][8] = sum(B['Oil'][1:174].tolist())

B = df.loc[df['Year'] == 2005]
A[25][0] = sum(B['Biomass and Waste'][1:174].tolist())
A[25][1] = sum(B['Geothermal'][1:174].tolist())
A[25][2] = sum(B['Hydroelectric'][1:174].tolist())
A[25][3] = sum(B['Nuclear'][1:174].tolist())
A[25][4] = sum(B['Solar Tide Wave'][1:174].tolist())
A[25][5] = sum(B['Wind'][1:174].tolist())
A[25][6] = sum(B['Coal'][1:174].tolist())
A[25][7] = sum(B['Gas'][1:174].tolist())
A[25][8] = sum(B['Oil'][1:174].tolist())

B = df.loc[df['Year'] == 2006]
A[26][0] = sum(B['Biomass and Waste'][1:174].tolist())
A[26][1] = sum(B['Geothermal'][1:174].tolist())
A[26][2] = sum(B['Hydroelectric'][1:174].tolist())
A[26][3] = sum(B['Nuclear'][1:174].tolist())
A[26][4] = sum(B['Solar Tide Wave'][1:174].tolist())
A[26][5] = sum(B['Wind'][1:174].tolist())
A[26][6] = sum(B['Coal'][1:174].tolist())
A[26][7] = sum(B['Gas'][1:174].tolist())
A[26][8] = sum(B['Oil'][1:174].tolist())

B = df.loc[df['Year'] == 2007]
A[27][0] = sum(B['Biomass and Waste'][1:174].tolist())
A[27][1] = sum(B['Geothermal'][1:174].tolist())
A[27][2] = sum(B['Hydroelectric'][1:174].tolist())
A[27][3] = sum(B['Nuclear'][1:174].tolist())
A[27][4] = sum(B['Solar Tide Wave'][1:174].tolist())
A[27][5] = sum(B['Wind'][1:174].tolist())
A[27][6] = sum(B['Coal'][1:174].tolist())
A[27][7] = sum(B['Gas'][1:174].tolist())
A[27][8] = sum(B['Oil'][1:174].tolist())

B = df.loc[df['Year'] == 2008]
A[28][0] = sum(B['Biomass and Waste'][1:174].tolist())
A[28][1] = sum(B['Geothermal'][1:174].tolist())
A[28][2] = sum(B['Hydroelectric'][1:174].tolist())
A[28][3] = sum(B['Nuclear'][1:174].tolist())
A[28][4] = sum(B['Solar Tide Wave'][1:174].tolist())
A[28][5] = sum(B['Wind'][1:174].tolist())
A[28][6] = sum(B['Coal'][1:174].tolist())
A[28][7] = sum(B['Gas'][1:174].tolist())
A[28][8] = sum(B['Oil'][1:174].tolist())

B = df.loc[df['Year'] == 2009]
A[29][0] = sum(B['Biomass and Waste'][1:174].tolist())
A[29][1] = sum(B['Geothermal'][1:174].tolist())
A[29][2] = sum(B['Hydroelectric'][1:174].tolist())
A[29][3] = sum(B['Nuclear'][1:174].tolist())
A[29][4] = sum(B['Solar Tide Wave'][1:174].tolist())
A[29][5] = sum(B['Wind'][1:174].tolist())
A[29][6] = sum(B['Coal'][1:174].tolist())
A[29][7] = sum(B['Gas'][1:174].tolist())
A[29][8] = sum(B['Oil'][1:174].tolist())

B = df.loc[df['Year'] == 2010]
A[30][0] = sum(B['Biomass and Waste'][1:174].tolist())
A[30][1] = sum(B['Geothermal'][1:174].tolist())
A[30][2] = sum(B['Hydroelectric'][1:174].tolist())
A[30][3] = sum(B['Nuclear'][1:174].tolist())
A[30][4] = sum(B['Solar Tide Wave'][1:174].tolist())
A[30][5] = sum(B['Wind'][1:174].tolist())
A[30][6] = sum(B['Coal'][1:174].tolist())
A[30][7] = sum(B['Gas'][1:174].tolist())
A[30][8] = sum(B['Oil'][1:174].tolist())

B = df.loc[df['Year'] == 2011]
A[31][0] = sum(B['Biomass and Waste'][1:174].tolist())
A[31][1] = sum(B['Geothermal'][1:174].tolist())
A[31][2] = sum(B['Hydroelectric'][1:174].tolist())
A[31][3] = sum(B['Nuclear'][1:174].tolist())
A[31][4] = sum(B['Solar Tide Wave'][1:174].tolist())
A[31][5] = sum(B['Wind'][1:174].tolist())
A[31][6] = sum(B['Coal'][1:174].tolist())
A[31][7] = sum(B['Gas'][1:174].tolist())
A[31][8] = sum(B['Oil'][1:174].tolist())

B = df.loc[df['Year'] == 2012]
A[32][0] = sum(B['Biomass and Waste'][1:174].tolist())
A[32][1] = sum(B['Geothermal'][1:174].tolist())
A[32][2] = sum(B['Hydroelectric'][1:174].tolist())
A[32][3] = sum(B['Nuclear'][1:174].tolist())
A[32][4] = sum(B['Solar Tide Wave'][1:174].tolist())
A[32][5] = sum(B['Wind'][1:174].tolist())
A[32][6] = sum(B['Coal'][1:174].tolist())
A[32][7] = sum(B['Gas'][1:174].tolist())
A[32][8] = sum(B['Oil'][1:174].tolist())

B = df.loc[df['Year'] == 2013]
A[33][0] = sum(B['Biomass and Waste'][1:174].tolist())
A[33][1] = sum(B['Geothermal'][1:174].tolist())
A[33][2] = sum(B['Hydroelectric'][1:174].tolist())
A[33][3] = sum(B['Nuclear'][1:174].tolist())
A[33][4] = sum(B['Solar Tide Wave'][1:174].tolist())
A[33][5] = sum(B['Wind'][1:174].tolist())
A[33][6] = sum(B['Coal'][1:174].tolist())
A[33][7] = sum(B['Gas'][1:174].tolist())
A[33][8] = sum(B['Oil'][1:174].tolist())

B = df.loc[df['Year'] == 2014]
A[34][0] = sum(B['Biomass and Waste'][1:174].tolist())
A[34][1] = sum(B['Geothermal'][1:174].tolist())
A[34][2] = sum(B['Hydroelectric'][1:174].tolist())
A[34][3] = sum(B['Nuclear'][1:174].tolist())
A[34][4] = sum(B['Solar Tide Wave'][1:174].tolist())
A[34][5] = sum(B['Wind'][1:174].tolist())
A[34][6] = sum(B['Coal'][1:174].tolist())
A[34][7] = sum(B['Gas'][1:174].tolist())
A[34][8] = sum(B['Oil'][1:174].tolist())

Biomass_waste = A[:,0];
Geo = A[:,1];
Hydro = A[:,2];
Nuclear = A[:,3];
Solar_tide_wave = A[:,4];
Wind = A[:,5];
Coal = A[:,6];
Gas = A[:,7];
Oil = A[:,8];

from scipy import interpolate
#Cubic-spline
x1 = np.array(year.tolist())
y1 = Biomass_waste
tck1 = interpolate.splrep(x1, y1, s=0)
x1new = range(1980,2022,1)
y1new = interpolate.splev(x1new, tck1, der=0)

x1 = np.array(year.tolist())
x1new = range(1980,2022,1)
y2 = Geo
tck2 = interpolate.splrep(x1, y2, s=0)
y2new = interpolate.splev(x1new, tck2, der=0)

x1 = np.array(year.tolist())
x1new = range(1980,2022,1)
y3 = Hydro
tck3 = interpolate.splrep(x1, y3, s=0)
y3new = interpolate.splev(x1new, tck3, der=0)

x1 = np.array(year.tolist())
x1new = range(1980,2022,1)
y4 = Nuclear
tck4 = interpolate.splrep(x1, y4, s=0)
y4new = interpolate.splev(x1new, tck4, der=0)

x1 = np.array(year.tolist())
x1new = range(1980,2022,1)
y5 = Solar_tide_wave
tck5 = interpolate.splrep(x1, y5, s=0)
y5new = interpolate.splev(x1new, tck5, der=0)

x1 = np.array(year.tolist())
x1new = range(1980,2022,1)
y6 = Wind
tck6 = interpolate.splrep(x1, y6, s=0)
y6new = interpolate.splev(x1new, tck6, der=0)

# Plot 4 : Projections of energy productions from 2014-2022 using spline interpolation
import matplotlib.pyplot as plt # plot charts
plt.plot(x1, y1,'b', x1new, y1new, 'b--')
plt.xlabel('Years', fontsize=5)
plt.title('Biomass and waste spline interpolation')
plt.show()
plt.plot(x1, y2,'g', x1new, y2new, 'g--')
plt.xlabel('Years', fontsize=5)
plt.title('Geothermal spline interpolation')
plt.show()
plt.plot(x1, y3,'r', x1new, y3new, 'r--')
plt.xlabel('Years', fontsize=5)
plt.title('Hydroelectric spline interpolation')
plt.show()
plt.plot(x1, y4,'c', x1new, y4new, 'c--')
plt.xlabel('Years', fontsize=5)
plt.title('Nuclear spline interpolation')
plt.show()
plt.plot(x1, y5,'m', x1new, y5new, 'm--')
plt.xlabel('Years', fontsize=5)
plt.title('Solar, Tide and Wave spline interpolation')
plt.show()
plt.plot(x1, y6,'y', x1new, y6new, 'y--')
plt.xlabel('Years', fontsize=5)
plt.title('Wind spline interpolation')
plt.show()

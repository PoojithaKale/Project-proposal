# %%
import pandas as pd # import and manage datasets
import numpy as np # mathematic library

# %%
India_RE_gen = pd.read_excel('India_RE_profile_1990-2018.xlsx')

# %%
India_RE_gen
# Out:
#     Year  Solar Generation TWh  Wind Generation TWh  Hydro Generation TWh  \
# 0   1990              0.000000             0.030303             66.397066
# 1   1991              0.000000             0.112910             73.918884
# 2   1992              0.000000             0.088470             70.060748
# 3   1993              0.000000             0.094770             70.732497
# 4   1994              0.000000             0.191280             80.212110
# 5   1995              0.001010             0.496470             75.920873
# 6   1996              0.006061             0.878380             69.057544
# 7   1997              0.006061             0.988000             70.211008
# 8   1998              0.006061             1.079000             83.632726
# 9   1999              0.006061             1.446000             82.249453
# 10  2000              0.007071             1.582000             76.990367
# 11  2001              0.011111             2.085000             72.022962
# 12  2002              0.013131             2.085000             68.544894
# 13  2003              0.016162             2.604480             69.296192
# 14  2004              0.018182             5.225430             83.840437
# 15  2005              0.018182             5.991000             97.420000
# 16  2006              0.007200             9.337300            112.617332
# 17  2007              0.059000            11.682800            122.613097
# 18  2008              0.063000            14.378200            115.169020
# 19  2009              0.075000            16.271000            106.338027
# 20  2010              0.113000            19.456400            108.744097
# 21  2011              0.827000            23.952300            131.704598
# 22  2012              2.099000            27.432600            115.776375
# 23  2013              3.433000            30.007400            131.983020
# 24  2014              4.909000            33.454900            138.996293
# 25  2015              6.566380            32.741380            133.282537
# 26  2016             11.555980            43.452830            128.381614
# 27  2017             21.522210            52.624950            135.668322
# 28  2018             30.732403            60.311160            139.667832
#
#     Geo, Biomass and other Generation TWh  RE Generation TWh  \
# 0                                0.037586           0.067889
# 1                                0.095071           0.207981
# 2                                0.119392           0.207862
# 3                                0.252050           0.346820
# 4                                0.380285           0.571565
# 5                                0.563795           1.061275
# 6                                0.756149           1.640589
# 7                                0.981667           1.975727
# 8                                1.292528           2.377588
# 9                                1.686079           3.138139
# 10                               1.686079           3.275150
# 11                               2.069150           4.165261
# 12                               2.139901           4.238032
# 13                               2.712540           5.333181
# 14                               3.314363           8.557975
# 15                               4.035136          10.044318
# 16                               5.587000          14.931500
# 17                               7.403000          19.144800
# 18                               9.302000          23.743200
# 19                              11.642000          27.988000
# 20                              14.295000          33.864400
# 21                              17.137000          41.916300
# 22                              19.936000          49.467600
# 23                              22.478000          55.918400
# 24                              24.676000          63.039900
# 25                              25.818000          65.125760
# 26                              24.816846          79.825656
# 27                              21.619790          95.766950
# 28                              30.458697         121.502260
#
#     RE Generation total TWh
# 0                 66.464955
# 1                 74.126866
# 2                 70.268610
# 3                 71.079317
# 4                 80.783675
# 5                 76.982148
# 6                 70.698134
# 7                 72.186735
# 8                 86.010314
# 9                 85.387593
# 10                80.265517
# 11                76.188223
# 12                72.782926
# 13                74.629373
# 14                92.398412
# 15               107.464318
# 16               127.548832
# 17               141.757898
# 18               138.912220
# 19               134.326028
# 20               142.608497
# 21               173.620898
# 22               165.243975
# 23               187.901420
# 24               202.036192
# 25               198.408297
# 26               208.207270
# 27               231.435272
# 28               261.170092

# %%
India_invest = pd.read_excel('investment_growth_forecast_2004-2030_India.xlsx')

# %%
India_invest
# Out:
#     year  solar_invest_pred  wind_invest_pred  hydro_invest_pred  \
# 0   2004          645787234        1130127659          155680851
# 1   2005          661771978        1186195054          307994505
# 2   2006          944401064        1711996450          323425022
# 3   2007         1633653483        2565969868          268775894
# 4   2008         1894727272        2312000000          234909090
# 5   2009         1537149270        1914231200          148911335
# 6   2010         3761084188        3688476386          294061601
# 7   2011         7039907539        3826728307          340860597
# 8   2012         4293970242        2577603758          195458104
# 9   2013         3333174061        2490784982          156723549
# 10  2014         4294750089        3238223660          191010427
# 11  2015         5589464915        4043165652          113937840
# 12  2016         5013546434        4275782123          115711219
# 13  2017         4470712860        4523159288          111994925
# 14  2018         5047972823        4777349087          108661585
# 15  2019         5761563982        5034701894          105301134
# 16  2020         5672652120        5293530772          101942625
# 17  2021         5510223332        5553051558           98583975
# 18  2022         5921350300        5812897948           95225336
# 19  2023         6422707513        6072898096           91866696
# 20  2024         6531953425        6332971076           88508056
# 21  2025         6594320358        6593078651           85149416
# 22  2026         6959975204        6853202701           81790776
# 23  2027         7381703263        7113334613           78432136
# 24  2028         7603116732        7373470285           75073496
# 25  2029         7804844549        7633607759           71714856
# 26  2030         8174715338        7893746098           68356216
#
#     other_invest_pred  T_invest_pred
# 0           778404255     2710000000
# 1           869876373     3030000000
# 2          1845678793     4860000000
# 3          2188003766     6690000000
# 4          1162181818     5610000000
# 5           672502805     4280000000
# 6          1089117043     8840000000
# 7          1563413940    12780000000
# 8           723805794     7800000000
# 9           573720136     6560000000
# 10          567062207     8300000000
# 11          406920858    10160000000
# 12          363610622    11237272471
# 13          328380020     7142867113
# 14          293715884     9866081977
# 15          259091940    11487036374
# 16          224470877    12590634628
# 17          189850023    13451205429
# 18          155229184    14197408627
# 19          120608346    14889604917
# 20           85987508    15556218981
# 21           51366670    16210681486
# 22           16745832    16859357539
# 23          -17875005    17505271874
# 24          -52495842    18149865386
# 25          -87116679    18793826005
# 26         -121737516    19437482834

# %%
India_energy = pd.read_excel("cent_elec_1993-2017.xlsx")

# %%
India_energy
# Out:
#     Year  Energy_con  Percentage_access  Population  cent_access
# 0   1993  222.645002          50.900000   909307016   437.416508
# 1   1994  234.439233          49.815136   927403860   470.618476
# 2   1995  252.180017          51.398556   945601831   490.636388
# 3   1996  262.524797          52.985596   963922588   495.464463
# 4   1997  277.143608          54.577168   982365243   507.801376
# 5   1998  293.718679          56.173199  1000900030   522.880459
# 6   1999  301.684249          60.100000  1019483581   501.970464
# 7   2000  317.536857          59.361851  1038058156   534.917381
# 8   2001  319.346376          55.800000  1056575549   572.305333
# 9   2002  334.305749          62.300000  1075000085   536.606338
# 10  2003  347.329780          64.062386  1093317189   542.174284
# 11  2004  367.767656          64.400000  1111523144   571.067789
# 12  2005  395.119424          67.086693  1129623456   588.968405
# 13  2006  415.437576          67.900000  1147609927   611.837373
# 14  2007  451.893499          70.052116  1165486291   645.081866
# 15  2008  477.864921          71.545509  1183209472   667.917421
# 16  2009  514.281940          75.000000  1200669765   685.709254
# 17  2010  539.152553          76.300000  1217726215   706.621957
# 18  2011  571.373058          67.600000  1234281170   845.226418
# 19  2012  601.043621          79.900000  1250288729   752.244833
# 20  2013  624.522137          80.874756  1265782790   772.208992
# 21  2014  667.518630          83.620110  1280846129   798.275239
# 22  2015  689.777879          88.000000  1295604184   783.838498
# 23  2016  719.252335          89.645859  1310152403   802.326338
# 24  2017  750.087830          92.618660  1324509589   809.866856

# %%
pop_growth = pd.read_excel("population_growth_forecast_1960-2030_India.xlsx")

# %%
pop_growth
# Out:
#       pop_pred  Year
# 0    450547679  1960
# 1    459642165  1961
# 2    469077190  1962
# 3    478825608  1963
# 4    488848135  1964
# 5    499123324  1965
# 6    509631500  1966
# 7    520400576  1967
# 8    531513824  1968
# 9    543084336  1969
# 10   555189792  1970
# 11   567868018  1971
# 12   581087256  1972
# 13   594770134  1973
# 14   608802600  1974
# 15   623102897  1975
# 16   637630087  1976
# 17   652408776  1977
# 18   667499806  1978
# 19   682995354  1979
# 20   698952844  1980
# 21   715384993  1981
# 22   732239504  1982
# 23   749428958  1983
# 24   766833410  1984
# 25   784360008  1985
# 26   801975244  1986
# 27   819682102  1987
# 28   837468930  1988
# 29   855334678  1989
# ..         ...   ...
# 41  1075000085  2001
# 42  1093317189  2002
# 43  1111523144  2003
# 44  1129623456  2004
# 45  1147609927  2005
# 46  1165486291  2006
# 47  1183209472  2007
# 48  1200669765  2008
# 49  1217726215  2009
# 50  1234281170  2010
# 51  1250288729  2011
# 52  1265782790  2012
# 53  1280846129  2013
# 54  1295604184  2014
# 55  1310152403  2015
# 56  1324509589  2016
# 57  1338658835  2017
# 58  1352617328  2018
# 59  1367359855  2019
# 60  1382892360  2020
# 61  1398431381  2021
# 62  1413970456  2022
# 63  1429509532  2023
# 64  1445048608  2024
# 65  1460587684  2025
# 66  1476126761  2026
# 67  1491665838  2027
# 68  1507204914  2028
# 69  1522743989  2029
# 70  1538283064  2030
#
# [71 rows x 2 columns]

# %%
len(list(India_invest['T_invest_pred']))
# Out:
# 27

# %%
len(list(range(2004,2018)))
# Out:
# 14

# %%
len(India_RE_gen['Solar Generation TWh'][14:])
# Out:
# 15

# %%
len(list(India_energy['Population'])[11:])
# Out:
# 14

# %%
# input is total_investment,investment_per_tech,population,year -> output is growth in RE generation
X1 = pd.DataFrame(list(range(2004,2018)), columns = ['Year'])
X1['T_invest'] = list(India_invest['T_invest_pred'])[:14]
X1['Solar_invest'] = list(India_invest['solar_invest_pred'])[:14]
X1['Population'] = list(India_energy['Population'])[11:]
Y1 = np.log(list(India_RE_gen['Solar Generation TWh'])[14:-1])

X1_train = X1[:10]
X1_test = X1[10:]
Y1_train = Y1[:10]
Y1_test = Y1[10:]

# %%
X1
# Out:
#     Year     T_invest  Solar_invest  Population
# 0   2004   2710000000     645787234  1111523144
# 1   2005   3030000000     661771978  1129623456
# 2   2006   4860000000     944401064  1147609927
# 3   2007   6690000000    1633653483  1165486291
# 4   2008   5610000000    1894727272  1183209472
# 5   2009   4280000000    1537149270  1200669765
# 6   2010   8840000000    3761084188  1217726215
# 7   2011  12780000000    7039907539  1234281170
# 8   2012   7800000000    4293970242  1250288729
# 9   2013   6560000000    3333174061  1265782790
# 10  2014   8300000000    4294750089  1280846129
# 11  2015  10160000000    5589464915  1295604184
# 12  2016  11237272471    5013546434  1310152403
# 13  2017   7142867113    4470712860  1324509589

# %%
forcast_X1 = pd.DataFrame(list(range(2017,2031)), columns = ['Year'], index = list(range(24,38)))

# %%
forcast_X1['T_invest'] = list(India_invest['T_invest_pred'])[13:]
forcast_X1['Solar_invest'] = list(India_invest['solar_invest_pred'])[13:]
forcast_X1['Population'] = list(pop_growth['pop_pred'][57:])

# %%
from sklearn.linear_model import Ridge

elec_pred1 = Ridge(alpha = 0.11)
elec_pred1.fit(X1_train,Y1_train)
y1_pred = elec_pred1.predict(X1_test)
from sklearn import metrics
print("R^2:", metrics.r2_score(y1_pred, Y1_test))
# Out:
# R^2: 0.6107705738352813
# C:\Users\pooji\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.053925e-21
#   overwrite_a=True).T

# %%
y2_pred = elec_pred1.predict(forcast_X1)

# %%
import matplotlib.pyplot as plt
plt.plot(X1['Year'], Y1, label='training data')
plt.plot(X1_test['Year'], y1_pred, label='test_predict data')
plt.plot(forcast_X1['Year'], y2_pred, '--', label='model prediction')
plt.legend()
plt.title('Logarithmic growth of Solar')
plt.show()

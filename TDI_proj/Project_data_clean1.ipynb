# %%
import pandas as pd # import and manage datasets
import numpy as np # mathematic library

excel_file = pd.ExcelFile('bp-stats-review-2019-all-data.xlsx')

# %%
df_tec2 = pd.read_excel(excel_file, 'Primary Energy Consumption') # tec --- total energy consumed

# %%
df_tec_NA = df_tec2[3:6]

# %%
df_tec_SCA = df_tec2[8:19]

# %%
df_tec_EU = df_tec2[21:55]

# %%
df_tec_CIS = df_tec2[57:65]

# %%
df_tec_ME = df_tec2[67:76]

# %%
df_tec_AF = df_tec2[78:87]

# %%
df_tec_A = df_tec2[89:107]

# %%
df_tec_W = df_tec2[109:110]

# %%
df_tec_years = df_tec2[1:2]

# %%
frames = [df_tec_NA, df_tec_SCA, df_tec_EU, df_tec_CIS, df_tec_ME, df_tec_AF, df_tec_A]

# %%
df_tec1 = pd.concat(frames)

# %%
df_tec1.rename(columns={'Primary Energy: Consumption*':'Total Energy',
                        'Unnamed: 1':'1965',
                        'Unnamed: 2':'1966',
                        'Unnamed: 3':'1967',
                        'Unnamed: 4':'1968',
                        'Unnamed: 5':'1969',
                        'Unnamed: 6':'1970',
                        'Unnamed: 7':'1971',
                        'Unnamed: 8':'1972',
                        'Contents':'1973',
                        'Unnamed: 10':'1974',
                        'Unnamed: 11':'1975',
                        'Unnamed: 12':'1976',
                        'Unnamed: 13':'1977',
                        'Unnamed: 14':'1978',
                        'Unnamed: 15':'1979',
                        'Unnamed: 16':'1980',
                        'Unnamed: 17':'1981',
                        'Unnamed: 18':'1982',
                        'Unnamed: 19':'1983',
                        'Unnamed: 20':'1984',
                        'Unnamed: 21':'1985',
                        'Unnamed: 22':'1986',
                        'Unnamed: 23':'1987',
                        'Unnamed: 24':'1988',
                        'Unnamed: 25':'1989',
                        'Unnamed: 26':'1990',
                        'Unnamed: 27':'1991',
                        'Unnamed: 28':'1992',
                        'Unnamed: 29':'1993',
                        'Unnamed: 30':'1994',
                        'Unnamed: 31':'1995',
                        'Unnamed: 32':'1996',
                        'Unnamed: 33':'1997',
                        'Unnamed: 34':'1998',
                        'Unnamed: 35':'1999',
                        'Unnamed: 36':'2000',
                        'Unnamed: 37':'2001',
                        'Unnamed: 38':'2002',
                        'Unnamed: 39':'2003',
                        'Unnamed: 40':'2004',
                        'Unnamed: 41':'2005',
                        'Unnamed: 42':'2006',
                        'Unnamed: 43':'2007',
                        'Unnamed: 44':'2008',
                        'Unnamed: 45':'2009',
                        'Unnamed: 46':'2010',
                        'Unnamed: 47':'2011',
                        'Unnamed: 48':'2012',
                        'Unnamed: 49':'2013',
                        'Unnamed: 50':'2014',
                        'Unnamed: 51':'2015',
                        'Unnamed: 52':'2016',
                        'Unnamed: 53':'2017',
                        'Unnamed: 54':'2018'},
                 inplace=True)

# %%
df_tec = df_tec1.reset_index()

# %%
df_tec.head()
# Out:
#    index Total Energy         1965         1966         1967         1968  \
# 0      3       Canada   115.910849   122.991657   129.026541   137.695457
# 1      4       Mexico    24.972964    26.432788    26.922222    29.291127
# 2      5           US  1249.642424  1320.037950  1365.733676  1448.932114
# 3      8    Argentina    26.914442    27.809713    28.635373    29.623572
# 4      9       Brazil    22.486225    24.529219    25.404553    29.122828
#
#           1969         1970         1971         1972     ...      \
# 0   145.303023   155.587992   159.794037   170.698240     ...
# 1    32.196346    34.320386    36.094722    39.916724     ...
# 2  1526.191928  1577.850993  1610.270681  1692.888180     ...
# 3    30.644712    28.937326    30.747979    31.299226     ...
# 4    31.813745    37.369778    40.871057    47.072428     ...
#
#           2014         2015         2016         2017         2018  \
# 0   341.813863   339.043046   338.223484   343.696739   344.424157
# ...

# %%
df_tec.to_excel("Total_Energy_Consumption_1965-2018.xlsx")

# %%
import plotly as py
from ipywidgets import interactive
import plotly.io as pio

# %%
def plotting(year):
    Z = df_tec[str(year)]
    map_y = {"data": [{"type" : 'choropleth',
                       "locations" : df_tec['Total Energy'],
                       "locationmode" : 'country names',
                       "colorscale" : 'Reds',
                       "z": Z}],
             "layout": {"title": {"text": "Energy consumed per year"}}}
    return pio.show(map_y)

interactive_plot = interactive(plotting, year = (1965,2018,1))
interactive_plot
# Out:
# interactive(children=(IntSlider(value=1991, description='year', max=2018, min=1965), Output()), _dom_classes=(…

# %%
year = df_tec_years.values.tolist()[0][1:55]

# %%
total_energy = df_tec_W.values.tolist()[0][1:55]

# %%
# Plot2: A graph showing total energy consumption from 1965-2018

import matplotlib.pyplot as plt # plot charts
plt.bar(year, total_energy, color='b')
plt.xlim((1965, 2018))
plt.xlabel('Years')
plt.ylabel('Million tonnes of oil equivalent (Mtoe)')
plt.title('Total energy consumed')
plt.show()

# %%
df_oil = pd.read_excel(excel_file, 'Oil Consumption - Mtoe') # --- energy from oil consumed 
df_oil_W = df_oil[109:110]
oil_energy = df_oil_W.values.tolist()[0][1:55]

# %%
df_gas = pd.read_excel(excel_file, 'Gas Consumption - Mtoe') # --- energy from gas consumed 
df_gas_W = df_gas[109:110]
gas_energy = df_gas_W.values.tolist()[0][1:55]

# %%
df_coal = pd.read_excel(excel_file, 'Coal Consumption - Mtoe') # --- energy from coal consumed 
df_coal_W = df_coal[109:110]
coal_energy = df_coal_W.values.tolist()[0][1:55]

# %%
df_nuc = pd.read_excel(excel_file, 'Nuclear Consumption - Mtoe') # --- energy from Nuclear consumed 
df_nuc_W = df_nuc[109:110]
nuc_energy = df_nuc_W.values.tolist()[0][1:55]

# %%
ren_energy = []  # --- energy from renewable sources
for i in range(len(year)):
    x = total_energy[i] - oil_energy[i] - gas_energy[i] - coal_energy[i] - nuc_energy[i]
    ren_energy = ren_energy + [x]

# %%
oil_gas = []
for i in range(len(year)):
    x = oil_energy[i] + gas_energy[i]
    oil_gas = oil_gas + [x]

# %%
oil_gas_coal = []
for i in range(len(year)):
    x = oil_energy[i] + gas_energy[i] + coal_energy[i]
    oil_gas_coal = oil_gas_coal + [x]

# %%
oil_gas_coal_nuc = []
for i in range(len(year)):
    x = oil_energy[i] + gas_energy[i] + coal_energy[i] + nuc_energy[i]
    oil_gas_coal_nuc = oil_gas_coal_nuc + [x]

# %%
plt.fill_between(year, oil_energy, color='y', alpha=0.5, label = 'Oil' )
plt.fill_between(year, oil_energy, oil_gas,color='g', alpha=0.5, label = 'Gas' )
plt.fill_between(year, oil_gas, oil_gas_coal, color='r', alpha=0.5,label = 'Coal')
plt.fill_between(year, oil_gas_coal, oil_gas_coal_nuc, color='m', alpha=0.5, label = 'Nuclear')
plt.fill_between(year, oil_gas_coal_nuc, total_energy, color='b', alpha=0.5, label = 'Renewable')
plt.xlabel('Years')
plt.xlim((1965, 2018))
plt.ylabel('Million tonnes of oil equivalent (Mtoe)')
plt.legend(loc='upper left')
plt.title('Distribution of energy among the different sources')
plt.show()

# %%
plt.plot(year, ren_energy)
plt.xlim((1965, 2018))
plt.xlabel('Years')
plt.ylabel('Million tonnes of oil equivalent (Mtoe)')
plt.title('Growth of renewable energy 1965-2018')
plt.show()

# %%
df_hydro = pd.read_excel(excel_file, 'Hydro Consumption - Mtoe') # --- energy from hydro consumed 
df_hydro_W = df_hydro[109:110]
hydro_energy = df_hydro_W.values.tolist()[0][1:55]

# %%
df_solar = pd.read_excel(excel_file, 'Solar Consumption - Mtoe') # --- energy from solar consumed 
df_solar_W = df_solar[109:110]
solar_energy = df_solar_W.values.tolist()[0][1:55]

# %%
df_wind = pd.read_excel(excel_file, 'Wind Consumption - Mtoe') # --- energy from wind consumed 
df_wind_W = df_wind[109:110]
wind_energy = df_wind_W.values.tolist()[0][1:55]

# %%
hydro_wind = []
for i in range(len(year)):
    x = hydro_energy[i] + wind_energy[i]
    hydro_wind = hydro_wind + [x]

# %%
hydro_wind_solar = []
for i in range(len(year)):
    x = hydro_energy[i] + wind_energy[i] + solar_energy[i]
    hydro_wind_solar = hydro_wind_solar + [x]

# %%
plt.fill_between(year, hydro_energy, color='b', alpha=0.5, label = 'Hydro' )
plt.fill_between(year, hydro_energy, hydro_wind,color='g', alpha=0.5, label = 'Wind' )
plt.fill_between(year, hydro_wind, hydro_wind_solar, color='y', alpha=0.5,label = 'Solar')
plt.fill_between(year, hydro_wind_solar, ren_energy, color='m', alpha=0.5, label = 'Geothermal, Biofuels and others')
plt.xlabel('Years')
plt.xlim((1965, 2018))
plt.ylabel('Million tonnes of oil equivalent (Mtoe)')
plt.legend(loc='upper left')
plt.title('Distribution of different forms of renewable energy among different sources')
plt.show()

# %%
excel_file2 = pd.read_csv('Access_electricity.csv')

# %%
excel_file2.head()
# Out:
#          Data Source World Development Indicators  \
# 0                NaN                          NaN
# 1  Last Updated Date                    10/2/2019
# 2                NaN                          NaN
# 3       Country Name                 Country Code
# 4              Aruba                          ABW
#
#                                 Unnamed: 2      Unnamed: 3  Unnamed: 4  \
# 0                                      NaN             NaN         NaN
# 1                                      NaN             NaN         NaN
# 2                                      NaN             NaN         NaN
# 3                           Indicator Name  Indicator Code      1960.0
# 4  Access to electricity (% of population)  EG.ELC.ACCS.ZS         NaN
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9     ...       \
# 0         NaN         NaN         NaN         NaN         NaN     ...
# 1         NaN         NaN         NaN         NaN         NaN     ...
# ...

# %%
df2 = excel_file2[4:]

# %%
df2.head()
# Out:
#    Data Source World Development Indicators  \
# 4        Aruba                          ABW
# 5  Afghanistan                          AFG
# 6       Angola                          AGO
# 7      Albania                          ALB
# 8      Andorra                          AND
#
#                                 Unnamed: 2      Unnamed: 3  Unnamed: 4  \
# 4  Access to electricity (% of population)  EG.ELC.ACCS.ZS         NaN
# 5  Access to electricity (% of population)  EG.ELC.ACCS.ZS         NaN
# 6  Access to electricity (% of population)  EG.ELC.ACCS.ZS         NaN
# 7  Access to electricity (% of population)  EG.ELC.ACCS.ZS         NaN
# 8  Access to electricity (% of population)  EG.ELC.ACCS.ZS         NaN
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9     ...       \
# 4         NaN         NaN         NaN         NaN         NaN     ...
# 5         NaN         NaN         NaN         NaN         NaN     ...
# ...

# %%
df2.rename(columns={    'Unnamed: 4':'1960',
                        'Unnamed: 5':'1961',
                        'Unnamed: 6':'1962',
                        'Unnamed: 7':'1963',
                        'Unnamed: 8':'1964',
                        'Unnamed: 9':'1965',
                        'Unnamed: 10':'1966',
                        'Unnamed: 11':'1967',
                        'Unnamed: 12':'1968',
                        'Unnamed: 13':'1969',
                        'Unnamed: 14':'1970',
                        'Unnamed: 15':'1971',
                        'Unnamed: 16':'1972',
                        'Unnamed: 17':'1973',
                        'Unnamed: 18':'1974',
                        'Unnamed: 19':'1975',
                        'Unnamed: 20':'1976',
                        'Unnamed: 21':'1977',
                        'Unnamed: 22':'1978',
                        'Unnamed: 23':'1979',
                        'Unnamed: 24':'1980',
                        'Unnamed: 25':'1981',
                        'Unnamed: 26':'1982',
                        'Unnamed: 27':'1983',
                        'Unnamed: 28':'1984',
                        'Unnamed: 29':'1985',
                        'Unnamed: 30':'1986',
                        'Unnamed: 31':'1987',
                        'Unnamed: 32':'1988',
                        'Unnamed: 33':'1989',
                        'Unnamed: 34':'1990',
                        'Unnamed: 35':'1991',
                        'Unnamed: 36':'1992',
                        'Unnamed: 37':'1993',
                        'Unnamed: 38':'1994',
                        'Unnamed: 39':'1995',
                        'Unnamed: 40':'1996',
                        'Unnamed: 41':'1997',
                        'Unnamed: 42':'1998',
                        'Unnamed: 43':'1999',
                        'Unnamed: 44':'2000',
                        'Unnamed: 45':'2001',
                        'Unnamed: 46':'2002',
                        'Unnamed: 47':'2003',
                        'Unnamed: 48':'2004',
                        'Unnamed: 49':'2005',
                        'Unnamed: 50':'2006',
                        'Unnamed: 51':'2007',
                        'Unnamed: 52':'2008',
                        'Unnamed: 53':'2009',
                        'Unnamed: 54':'2010',
                        'Unnamed: 55':'2011',
                        'Unnamed: 56':'2012',
                        'Unnamed: 57':'2013',
                        'Unnamed: 58':'2014',
                        'Unnamed: 59':'2015',
                        'Unnamed: 60':'2016',
                        'Unnamed: 61':'2017'},
                 inplace=True)
# Out:
# C:\Users\pooji\Anaconda3\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
def plotting2(year):
    Z = df2[str(year)]
    map_y = {"data": [{"type" : 'choropleth',
                       "locations" : df2['Data Source'],
                       "locationmode" : 'country names',
                       "colorscale" : 'Greens',
                       "z": Z}],
             "layout": {"title": {"text": "Percentage of population with access to electricity"}}}
    return pio.show(map_y)

interactive_plot2 = interactive(plotting2, year = (1990,2017,1))
interactive_plot2
# Out:
# interactive(children=(IntSlider(value=2003, description='year', max=2017, min=1990), Output()), _dom_classes=(…

# %%
import matplotlib.pyplot as plt
# Import a scoring metric to compare methods
from sklearn.metrics import r2_score

# %%
ts_series = df2[['Data Source','1990','1991','1992','1993','1994','1995','1996','1997', '1998', '1999',
                 '2000','2001','2002','2003','2004','2005','2006','2007','2008','2009',
                 '2010','2011','2012','2013','2014','2015','2016','2017',]]

# %%
countries = list(ts_series['Data Source'])

# %%
countries
# Out:
# ['Aruba',
#  'Afghanistan',
#  'Angola',
#  'Albania',
#  'Andorra',
#  'Arab World',
#  'United Arab Emirates',
#  'Argentina',
#  'Armenia',
#  'American Samoa',
#  'Antigua and Barbuda',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Burundi',
#  'Belgium',
#  'Benin',
#  'Burkina Faso',
#  'Bangladesh',
#  'Bulgaria',
#  'Bahrain',
#  'Bahamas, The',
#  'Bosnia and Herzegovina',
#  'Belarus',
#  'Belize',
#  'Bermuda',
#  'Bolivia',
#  'Brazil',
#  'Barbados',
#  'Brunei Darussalam',
#  'Bhutan',
#  'Botswana',
#  'Central African Republic',
#  'Canada',
#  'Central Europe and the Baltics',
#  'Switzerland',
#  'Channel Islands',
#  'Chile',
#  'China',
#  "Cote d'Ivoire",
#  'Cameroon',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  'Colombia',
#  'Comoros',
#  'Cabo Verde',
#  'Costa Rica',
#  'Caribbean small states',
#  'Cuba',
#  'Curacao',
#  'Cayman Islands',
#  'Cyprus',
#  'Czech Republic',
#  'Germany',
#  'Djibouti',
#  'Dominica',
#  'Denmark',
# ...

# %%
ts_series1 = ts_series.assign(missing= np.nan)

# %%
ts_series1 = ts_series1.set_index('Data Source')

# %%
ts_series1.to_excel("Access2Electricity_1990-2017.xlsx")

# %%
ts_series1.head()
# Out:
#               1990        1991        1992        1993   1994   1995   1996  \
# Data Source
# Aruba        100.0   99.276871   99.290588   99.305206  100.0  100.0  100.0
# Afghanistan    NaN         NaN         NaN         NaN    NaN    NaN    NaN
# Angola         NaN         NaN         NaN         NaN    NaN    NaN    NaN
# Albania      100.0  100.000000  100.000000  100.000000  100.0  100.0  100.0
# Andorra      100.0  100.000000  100.000000  100.000000  100.0  100.0  100.0
#
#               1997   1998   1999   ...           2009        2010        2011  \
# Data Source                        ...
# Aruba        100.0  100.0  100.0   ...     100.000000   93.356292  100.000000
# Afghanistan    NaN    NaN    NaN   ...      45.237122   42.700000   43.222019
# Angola         NaN    NaN    NaN   ...      32.287685   33.368420   34.600000
# Albania      100.0  100.0  100.0   ...     100.000000  100.000000  100.000000
# ...

# %%
year = range(1990,2018)
data_c = []
for i in year:
    data_c.append([str(i), ts_series1.loc['Afghanistan', str(i)]])      # str(countries)

# %%
data_c
# Out:
# [['1990', nan],
#  ['1991', nan],
#  ['1992', nan],
#  ['1993', nan],
#  ['1994', nan],
#  ['1995', nan],
#  ['1996', nan],
#  ['1997', nan],
#  ['1998', nan],
#  ['1999', nan],
#  ['2000', nan],
#  ['2001', nan],
#  ['2002', nan],
#  ['2003', nan],
#  ['2004', nan],
#  ['2005', 23.0],
#  ['2006', 26.92931747],
#  ['2007', 33.01575089],
#  ['2008', 42.4],
#  ['2009', 45.23712158],
#  ['2010', 42.7],
#  ['2011', 43.22201891],
#  ['2012', 69.1],
#  ['2013', 70.15348053],
#  ['2014', 89.5],
#  ['2015', 71.5],
#  ['2016', 97.7],
#  ['2017', 97.7]]

# %%
df_C = pd.DataFrame(data_c, columns = ['Date', 'A2E'+'Afghanistan'])

# %%
df_C.head()
# Out:
#    Date  A2EAfghanistan
# 0  1990             NaN
# 1  1991             NaN
# 2  1992             NaN
# 3  1993             NaN
# 4  1994             NaN

# %%
df_C['Date'] = pd.to_datetime(df_C['Date'])
df_C = df_C.set_index('Date')

# %%
df_C.head()
# Out:
#             A2EAfghanistan
# Date
# 1990-01-01             NaN
# 1991-01-01             NaN
# 1992-01-01             NaN
# 1993-01-01             NaN
# 1994-01-01             NaN

# %%
df_C = df_C.assign(InterpolateLinear =df_C['A2E'+'Afghanistan'].interpolate(method='linear', limit_direction='backward'))

# %%
df_C = df_C.assign(InterpolateSpline =df_C['A2E'+'Afghanistan'].interpolate(method='spline', order = 1, limit_direction='backward'))

# %%
df_C = df_C.assign(InterpolateTime = df_C['A2EAfghanistan'].interpolate(method='time', limit_direction='backward'))

# %%
df_C = df_C.assign(InterpolateAkima =df_C['A2E'+'Afghanistan'].interpolate(method='akima', limit_direction='backward'))

# %%
# imputing using the rolling average
df_C  = df_C.assign(RollingMean=df_C['A2E'+'Afghanistan'].fillna(df_C['A2E'+'Afghanistan'].rolling(window = 16 ).mean()))

# %%
# imputing using the rolling median
df_C = df_C.assign(RollingMedian=df_C['A2E'+'Afghanistan'].fillna(df_C['A2E'+'Afghanistan'].rolling(window = 16).median()))

# %%
df_C
# Out:
#             A2EAfghanistan  InterpolateLinear  InterpolateSpline  \
# Date
# 1990-01-01             NaN          23.000000         -54.326617
# 1991-01-01             NaN          23.000000         -49.203092
# 1992-01-01             NaN          23.000000         -44.079567
# 1993-01-01             NaN          23.000000         -38.942005
# 1994-01-01             NaN          23.000000         -33.818480
# 1995-01-01             NaN          23.000000         -28.694955
# 1996-01-01             NaN          23.000000         -23.571430
# 1997-01-01             NaN          23.000000         -18.433867
# 1998-01-01             NaN          23.000000         -13.310342
# 1999-01-01             NaN          23.000000          -8.186817
# 2000-01-01             NaN          23.000000          -3.063292
# 2001-01-01             NaN          23.000000           2.074270
# 2002-01-01             NaN          23.000000           7.197795
# ...

# %%
df_Central_African_Republic =
